# %% [markdown]
# <a href="https://colab.research.google.com/github/Declan-Bracken/Khthon/blob/master/grid_search.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install ultralytics

# %%
import requests
from PIL import Image
from io import BytesIO
import numpy as np
from ultralytics import YOLO

# %%
# Function to fetch a satellite image from Google Maps API
def fetch_image(latitude, longitude, zoom=18, size=(640, 640), maptype='satellite', api_key=None):
    url = f"https://maps.googleapis.com/maps/api/staticmap?center={latitude},{longitude}&zoom={zoom}&size={size[0]}x{size[1]}&maptype={maptype}&key={api_key}"
    response = requests.get(url)
    image = Image.open(BytesIO(response.content))
    return image

# %%
# Dictionary to map zoom levels to area sizes (in kilometers) covered by the image
zoom_to_area = {
    18: 0.36,  # Example: Zoom level 18 covers ~0.36 square km
    19: 0.18,  # Zoom level 19 covers ~0.18 square km
    # Add more zoom levels if needed
}

# %%
# Function to preprocess images and perform inference using YOLO model
def detect_churches(image, model):
    results = model(image)
    return results[0].boxes, results[0].names  # Return bounding boxes detected

# %%
# Function to generate grid coordinates within a specified area
def generate_grid(center_lat, center_lon, area_km, img_size=0.36):  # 0.36 km for zoom level 18
    lat_range = area_km / 111.32  # 1 degree of latitude ~ 111.32 km
    lon_range = area_km / (111.32 * np.cos(center_lat * np.pi / 180))

    lat_img = img_size / 111.32
    lon_img = img_size / (111.32 * np.cos(center_lat * np.pi / 180))

    latitudes = np.arange(center_lat - lat_range/2, center_lat + lat_range/2, lat_img)
    longitudes = np.arange(center_lon - lon_range/2, center_lon + lon_range/2, lon_img)

    grid_coords = [(lat, lon) for lat in latitudes for lon in longitudes]
    return grid_coords

# %%
def bbox_to_coords(bbox, grid_coord, image_size=(640, 640), zoom=18):
    lat, lon = grid_coord
    lat_per_pixel = 0.36 / 111.32 / image_size[0]  # Latitude degrees per pixel (assuming zoom 18, adjust as necessary)
    lon_per_pixel = 0.36 / (111.32 * np.cos(lat * np.pi / 180)) / image_size[1]  # Longitude degrees per pixel

    # Bounding box coordinates (left, top, right, bottom)
    left, top, right, bottom = bbox.xyxy[0].tolist()  # Convert tensor to list of floats

    # Convert to geographic coordinates
    church_lat = lat + (top + bottom) / 2 * lat_per_pixel - 0.18 / 111.32  # Adjust for grid center
    church_lon = lon + (left + right) / 2 * lon_per_pixel - 0.18 / (111.32 * np.cos(lat * np.pi / 180))

    return float(church_lat), float(church_lon)

    return church_lat, church_lon

# %%
# Main function to perform grid search for churches
def grid_search_churches(center_lat, center_lon, total_area_km=100, zoom=18, api_key=None, model_path='/content/best.pt'):
    img_size = zoom_to_area[zoom]
    grid_coords = generate_grid(center_lat, center_lon, total_area_km, img_size=img_size)

    model = YOLO(model_path)  # Load the YOLO model
    total_detections = 0
    church_info = []  # To store (latitude, longitude, class) for each detected church

    for coord in grid_coords:
        image = fetch_image(coord[0], coord[1], zoom=zoom, api_key=api_key)
        boxes, class_names = detect_churches(image, model)
        total_detections += len(boxes)  # Count the number of detected churches

        for bbox in boxes:
            church_lat, church_lon = bbox_to_coords(bbox, coord)
            church_class = class_names[int(bbox.cls)]  # Get the class label from the model
            church_name = bbox.cls_name if 'cls_name' in bbox else "Unknown Church"
            church_info.append((church_lat, church_lon, church_class, church_name))

    return total_detections, church_info

# %%
if __name__ == "__main__":
    api_key = 'AIzaSyBtj5oe5uH8pEa29JTEMk19rKuX4YBsP5k'
    center_lat, center_lon = (9.105673, 38.646501)  # Example coordinates (St. Kidane Mihret Church)
    total_area_km = 10  # 100 square km
    zoom = 18

    # Perform grid search and print the total number of detected churches and their coordinates and classes
    total_churches_detected, church_info = grid_search_churches(center_lat, center_lon, total_area_km=total_area_km, zoom=zoom, api_key=api_key)
    print(f"Total number of churches detected in the {total_area_km} sq km area: {total_churches_detected}")
    print("Coordinates and types of detected churches:")
    for info in church_info:
        print(f"Coordinates: ({info[0]}, {info[1]}), Type: {info[2]}, Name: {info[3]}")
# Out:
# 0: 640x640 (no detections), 233.5ms
# Speed: 5.2ms preprocess, 233.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 253.5ms
# Speed: 6.2ms preprocess, 253.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 octagon-churchs, 262.7ms
# Speed: 5.8ms preprocess, 262.7ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 275.9ms
# Speed: 5.9ms preprocess, 275.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 octagon-churchs, 234.5ms
# Speed: 4.4ms preprocess, 234.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 octagon-church, 247.3ms
# Speed: 3.8ms preprocess, 247.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 octagon-church, 223.6ms
# Speed: 4.3ms preprocess, 223.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 230.1ms
# Speed: 3.8ms preprocess, 230.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 255.6ms
# Speed: 2.3ms preprocess, 255.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 octagon-church, 280.7ms
# Speed: 2.9ms preprocess, 280.7ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 264.4ms
# Speed: 6.4ms preprocess, 264.4ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 256.9ms
# Speed: 5.8ms preprocess, 256.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 octagon-church, 282.2ms
# Speed: 5.1ms preprocess, 282.2ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 236.1ms
# Speed: 2.8ms preprocess, 236.1ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 octagon-church, 254.2ms
# Speed: 4.2ms preprocess, 254.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 244.8ms
# Speed: 4.6ms preprocess, 244.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 square-church, 237.9ms
# Speed: 2.5ms preprocess, 237.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 octagon-church, 221.2ms
# Speed: 2.5ms preprocess, 221.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 322.0ms
# Speed: 4.4ms preprocess, 322.0ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 octagon-church, 392.9ms
# Speed: 6.4ms preprocess, 392.9ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 358.8ms
# Speed: 6.6ms preprocess, 358.8ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 octagon-church, 365.9ms
# Speed: 3.8ms preprocess, 365.9ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 square-church, 384.6ms
# Speed: 6.7ms preprocess, 384.6ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 378.1ms
# Speed: 6.5ms preprocess, 378.1ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 231.4ms
# Speed: 3.9ms preprocess, 231.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 234.8ms
# Speed: 4.8ms preprocess, 234.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 octagon-church, 234.7ms
# Speed: 3.9ms preprocess, 234.7ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 octagon-church, 243.4ms
# Speed: 3.0ms preprocess, 243.4ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 233.6ms
# Speed: 4.4ms preprocess, 233.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 233.3ms
# Speed: 2.4ms preprocess, 233.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 247.0ms
# Speed: 4.0ms preprocess, 247.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 260.4ms
# Speed: 4.9ms preprocess, 260.4ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 octagon-church, 284.4ms
# Speed: 5.1ms preprocess, 284.4ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 242.2ms
# Speed: 3.1ms preprocess, 242.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 240.2ms
# Speed: 3.9ms preprocess, 240.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 245.6ms
# Speed: 2.9ms preprocess, 245.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 287.6ms
# Speed: 5.7ms preprocess, 287.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 306.0ms
# Speed: 6.3ms preprocess, 306.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 284.7ms
# Speed: 4.2ms preprocess, 284.7ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 295.5ms
# Speed: 6.7ms preprocess, 295.5ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 276.1ms
# Speed: 6.2ms preprocess, 276.1ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 267.4ms
# Speed: 6.2ms preprocess, 267.4ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 square-church, 270.4ms
# Speed: 5.6ms preprocess, 270.4ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 octagon-church, 260.2ms
# Speed: 5.5ms preprocess, 260.2ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 octagon-church, 283.0ms
# Speed: 2.9ms preprocess, 283.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 octagon-church, 261.4ms
# Speed: 5.9ms preprocess, 261.4ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 octagon-church, 280.8ms
# Speed: 8.3ms preprocess, 280.8ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 414.9ms
# Speed: 6.8ms preprocess, 414.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 415.7ms
# Speed: 4.2ms preprocess, 415.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 414.8ms
# Speed: 9.4ms preprocess, 414.8ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 428.2ms
# Speed: 11.6ms preprocess, 428.2ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 octagon-church, 413.3ms
# Speed: 6.5ms preprocess, 413.3ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 372.6ms
# Speed: 5.0ms preprocess, 372.6ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 5 octagon-churchs, 280.0ms
# Speed: 5.5ms preprocess, 280.0ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 circle-church, 1 octagon-church, 271.8ms
# Speed: 6.5ms preprocess, 271.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 circle-church, 1 octagon-church, 287.8ms
# Speed: 7.0ms preprocess, 287.8ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 octagon-church, 284.7ms
# Speed: 3.3ms preprocess, 284.7ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 square-church, 257.8ms
# Speed: 4.7ms preprocess, 257.8ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 octagon-church, 300.6ms
# Speed: 6.7ms preprocess, 300.6ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 305.3ms
# Speed: 6.6ms preprocess, 305.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 octagon-churchs, 281.0ms
# Speed: 3.3ms preprocess, 281.0ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 octagon-church, 287.8ms
# Speed: 5.5ms preprocess, 287.8ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 268.1ms
# Speed: 2.9ms preprocess, 268.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 285.5ms
# Speed: 4.5ms preprocess, 285.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 265.7ms
# Speed: 3.0ms preprocess, 265.7ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 267.0ms
# Speed: 2.9ms preprocess, 267.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 267.8ms
# Speed: 5.9ms preprocess, 267.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 251.7ms
# Speed: 3.2ms preprocess, 251.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 octagon-church, 269.0ms
# Speed: 6.0ms preprocess, 269.0ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 299.6ms
# Speed: 3.3ms preprocess, 299.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 octagon-church, 297.4ms
# Speed: 5.8ms preprocess, 297.4ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 octagon-churchs, 258.4ms
# Speed: 3.0ms preprocess, 258.4ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 265.2ms
# Speed: 5.1ms preprocess, 265.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 255.9ms
# Speed: 3.1ms preprocess, 255.9ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 249.5ms
# Speed: 4.6ms preprocess, 249.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 346.4ms
# Speed: 5.0ms preprocess, 346.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 octagon-church, 393.9ms
# Speed: 6.9ms preprocess, 393.9ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 octagon-church, 440.4ms
# Speed: 13.8ms preprocess, 440.4ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 434.9ms
# Speed: 8.0ms preprocess, 434.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 421.2ms
# Speed: 5.5ms preprocess, 421.2ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 403.5ms
# Speed: 6.5ms preprocess, 403.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 octagon-churchs, 273.2ms
# Speed: 5.5ms preprocess, 273.2ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 octagon-church, 273.7ms
# Speed: 4.5ms preprocess, 273.7ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 octagon-church, 261.6ms
# Speed: 4.2ms preprocess, 261.6ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 256.5ms
# Speed: 4.9ms preprocess, 256.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 282.5ms
# Speed: 4.6ms preprocess, 282.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 247.6ms
# Speed: 2.8ms preprocess, 247.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 259.3ms
# Speed: 5.1ms preprocess, 259.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 octagon-church, 303.4ms
# Speed: 7.6ms preprocess, 303.4ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 octagon-church, 290.2ms
# Speed: 6.0ms preprocess, 290.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 257.0ms
# Speed: 3.2ms preprocess, 257.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 octagon-church, 1 square-church, 250.6ms
# Speed: 2.9ms preprocess, 250.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 square-church, 261.4ms
# Speed: 2.7ms preprocess, 261.4ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 229.4ms
# Speed: 4.5ms preprocess, 229.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 square-church, 245.5ms
# Speed: 3.8ms preprocess, 245.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 281.6ms
# Speed: 6.4ms preprocess, 281.6ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 272.7ms
# Speed: 3.9ms preprocess, 272.7ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 square-church, 277.8ms
# Speed: 6.1ms preprocess, 277.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 238.3ms
# Speed: 2.8ms preprocess, 238.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 octagon-church, 240.0ms
# Speed: 3.7ms preprocess, 240.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 octagon-church, 229.4ms
# Speed: 2.4ms preprocess, 229.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 236.1ms
# Speed: 4.0ms preprocess, 236.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 253.0ms
# Speed: 4.6ms preprocess, 253.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 octagon-church, 238.0ms
# Speed: 2.8ms preprocess, 238.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 octagon-church, 234.5ms
# Speed: 6.1ms preprocess, 234.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 octagon-church, 367.0ms
# Speed: 9.4ms preprocess, 367.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 362.0ms
# Speed: 5.1ms preprocess, 362.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 351.9ms
# Speed: 3.2ms preprocess, 351.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 367.1ms
# Speed: 3.8ms preprocess, 367.1ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 380.4ms
# Speed: 6.4ms preprocess, 380.4ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 octagon-church, 365.2ms
# Speed: 7.1ms preprocess, 365.2ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 255.2ms
# Speed: 4.1ms preprocess, 255.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 232.5ms
# Speed: 2.8ms preprocess, 232.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 248.0ms
# Speed: 4.0ms preprocess, 248.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 230.0ms
# Speed: 2.4ms preprocess, 230.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 octagon-church, 235.6ms
# Speed: 3.9ms preprocess, 235.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 239.9ms
# Speed: 4.7ms preprocess, 239.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 circle-church, 238.6ms
# Speed: 2.4ms preprocess, 238.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 square-churchs, 264.8ms
# Speed: 4.9ms preprocess, 264.8ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 octagon-church, 259.2ms
# Speed: 6.0ms preprocess, 259.2ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 267.4ms
# Speed: 5.2ms preprocess, 267.4ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 octagon-church, 226.3ms
# Speed: 4.6ms preprocess, 226.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 262.8ms
# Speed: 5.2ms preprocess, 262.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 octagon-church, 246.7ms
# Speed: 2.8ms preprocess, 246.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 229.8ms
# Speed: 3.9ms preprocess, 229.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 octagon-church, 235.0ms
# Speed: 5.4ms preprocess, 235.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 octagon-church, 232.4ms
# Speed: 2.5ms preprocess, 232.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 239.9ms
# Speed: 4.6ms preprocess, 239.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 octagon-church, 259.5ms
# Speed: 5.1ms preprocess, 259.5ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 octagon-church, 268.5ms
# Speed: 4.8ms preprocess, 268.5ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 octagon-churchs, 261.9ms
# Speed: 6.1ms preprocess, 261.9ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 octagon-church, 280.7ms
# Speed: 5.8ms preprocess, 280.7ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 268.5ms
# Speed: 3.0ms preprocess, 268.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 octagon-church, 259.2ms
# Speed: 4.3ms preprocess, 259.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 octagon-church, 248.6ms
# Speed: 2.9ms preprocess, 248.6ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 octagon-churchs, 1 square-church, 439.0ms
# Speed: 6.0ms preprocess, 439.0ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 octagon-church, 445.8ms
# Speed: 7.9ms preprocess, 445.8ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 octagon-church, 405.1ms
# Speed: 6.7ms preprocess, 405.1ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 octagon-church, 416.6ms
# Speed: 7.5ms preprocess, 416.6ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 octagon-churchs, 416.4ms
# Speed: 6.7ms preprocess, 416.4ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 414.9ms
# Speed: 7.1ms preprocess, 414.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 338.0ms
# Speed: 8.8ms preprocess, 338.0ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 264.1ms
# Speed: 3.0ms preprocess, 264.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 234.6ms
# Speed: 3.1ms preprocess, 234.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 228.2ms
# Speed: 3.9ms preprocess, 228.2ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 octagon-churchs, 253.6ms
# Speed: 4.4ms preprocess, 253.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 octagon-church, 229.4ms
# Speed: 2.4ms preprocess, 229.4ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 octagon-churchs, 252.3ms
# Speed: 5.0ms preprocess, 252.3ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 264.1ms
# Speed: 3.4ms preprocess, 264.1ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 octagon-church, 258.3ms
# Speed: 6.2ms preprocess, 258.3ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 245.3ms
# Speed: 4.5ms preprocess, 245.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 octagon-church, 236.0ms
# Speed: 2.3ms preprocess, 236.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 octagon-churchs, 243.5ms
# Speed: 4.5ms preprocess, 243.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 235.3ms
# Speed: 4.6ms preprocess, 235.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 octagon-church, 233.0ms
# Speed: 4.2ms preprocess, 233.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 241.5ms
# Speed: 2.5ms preprocess, 241.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 244.7ms
# Speed: 3.9ms preprocess, 244.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 octagon-church, 242.9ms
# Speed: 2.7ms preprocess, 242.9ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 octagon-churchs, 276.6ms
# Speed: 4.8ms preprocess, 276.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 octagon-churchs, 260.1ms
# Speed: 3.2ms preprocess, 260.1ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 283.4ms
# Speed: 5.2ms preprocess, 283.4ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 256.0ms
# Speed: 3.1ms preprocess, 256.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 288.1ms
# Speed: 3.3ms preprocess, 288.1ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 octagon-churchs, 264.9ms
# Speed: 3.0ms preprocess, 264.9ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 octagon-church, 266.0ms
# Speed: 6.2ms preprocess, 266.0ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 octagon-churchs, 410.8ms
# Speed: 7.8ms preprocess, 410.8ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 393.0ms
# Speed: 6.7ms preprocess, 393.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 circle-church, 417.0ms
# Speed: 4.2ms preprocess, 417.0ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 423.0ms
# Speed: 7.1ms preprocess, 423.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 352.9ms
# Speed: 5.0ms preprocess, 352.9ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 264.3ms
# Speed: 5.7ms preprocess, 264.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 235.1ms
# Speed: 3.3ms preprocess, 235.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 octagon-church, 245.5ms
# Speed: 4.0ms preprocess, 245.5ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 292.7ms
# Speed: 5.8ms preprocess, 292.7ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 octagon-church, 270.2ms
# Speed: 3.7ms preprocess, 270.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 octagon-church, 239.9ms
# Speed: 4.9ms preprocess, 239.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 229.8ms
# Speed: 4.4ms preprocess, 229.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 258.8ms
# Speed: 3.0ms preprocess, 258.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 272.2ms
# Speed: 6.0ms preprocess, 272.2ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 250.5ms
# Speed: 3.8ms preprocess, 250.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 228.7ms
# Speed: 5.1ms preprocess, 228.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 259.1ms
# Speed: 4.9ms preprocess, 259.1ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 271.5ms
# Speed: 3.1ms preprocess, 271.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 267.1ms
# Speed: 6.0ms preprocess, 267.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 286.9ms
# Speed: 5.0ms preprocess, 286.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 281.1ms
# Speed: 2.9ms preprocess, 281.1ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 279.5ms
# Speed: 5.2ms preprocess, 279.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 octagon-church, 254.0ms
# Speed: 3.1ms preprocess, 254.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 238.9ms
# Speed: 4.3ms preprocess, 238.9ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 circle-church, 236.5ms
# Speed: 3.0ms preprocess, 236.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 octagon-churchs, 262.7ms
# Speed: 4.7ms preprocess, 262.7ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 octagon-church, 390.1ms
# Speed: 7.9ms preprocess, 390.1ms inference, 5.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 376.9ms
# Speed: 5.1ms preprocess, 376.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 octagon-church, 358.5ms
# Speed: 3.7ms preprocess, 358.5ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 361.5ms
# Speed: 3.2ms preprocess, 361.5ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 circle-church, 353.6ms
# Speed: 6.2ms preprocess, 353.6ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 304.7ms
# Speed: 5.5ms preprocess, 304.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 227.4ms
# Speed: 2.4ms preprocess, 227.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 264.1ms
# Speed: 3.7ms preprocess, 264.1ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 233.6ms
# Speed: 2.5ms preprocess, 233.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 268.5ms
# Speed: 5.0ms preprocess, 268.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 253.8ms
# Speed: 3.8ms preprocess, 253.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 octagon-churchs, 250.4ms
# Speed: 5.0ms preprocess, 250.4ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 285.6ms
# Speed: 5.9ms preprocess, 285.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 256.1ms
# Speed: 2.9ms preprocess, 256.1ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 275.8ms
# Speed: 6.3ms preprocess, 275.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 267.0ms
# Speed: 5.9ms preprocess, 267.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 266.6ms
# Speed: 5.8ms preprocess, 266.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 288.5ms
# Speed: 5.7ms preprocess, 288.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 262.9ms
# Speed: 3.6ms preprocess, 262.9ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 266.8ms
# Speed: 4.2ms preprocess, 266.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 262.9ms
# Speed: 5.9ms preprocess, 262.9ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 296.7ms
# Speed: 5.0ms preprocess, 296.7ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 octagon-church, 238.2ms
# Speed: 3.0ms preprocess, 238.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 246.9ms
# Speed: 3.9ms preprocess, 246.9ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 241.5ms
# Speed: 2.4ms preprocess, 241.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 233.1ms
# Speed: 2.4ms preprocess, 233.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 240.5ms
# Speed: 3.2ms preprocess, 240.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 octagon-church, 323.4ms
# Speed: 3.0ms preprocess, 323.4ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 octagon-churchs, 386.9ms
# Speed: 4.0ms preprocess, 386.9ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 366.0ms
# Speed: 5.6ms preprocess, 366.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 365.7ms
# Speed: 6.6ms preprocess, 365.7ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 406.5ms
# Speed: 3.3ms preprocess, 406.5ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 363.0ms
# Speed: 7.0ms preprocess, 363.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 octagon-church, 262.6ms
# Speed: 6.2ms preprocess, 262.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 243.1ms
# Speed: 4.0ms preprocess, 243.1ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 268.4ms
# Speed: 3.0ms preprocess, 268.4ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 255.5ms
# Speed: 4.6ms preprocess, 255.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 267.2ms
# Speed: 3.6ms preprocess, 267.2ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 octagon-church, 265.5ms
# Speed: 3.0ms preprocess, 265.5ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 258.3ms
# Speed: 6.5ms preprocess, 258.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 273.3ms
# Speed: 6.9ms preprocess, 273.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 250.2ms
# Speed: 4.2ms preprocess, 250.2ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 240.8ms
# Speed: 2.5ms preprocess, 240.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 246.7ms
# Speed: 4.3ms preprocess, 246.7ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 276.6ms
# Speed: 5.8ms preprocess, 276.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 292.3ms
# Speed: 4.0ms preprocess, 292.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 octagon-church, 268.6ms
# Speed: 6.5ms preprocess, 268.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 272.8ms
# Speed: 6.3ms preprocess, 272.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 269.4ms
# Speed: 5.2ms preprocess, 269.4ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 276.2ms
# Speed: 3.2ms preprocess, 276.2ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 244.4ms
# Speed: 4.5ms preprocess, 244.4ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 233.4ms
# Speed: 4.6ms preprocess, 233.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 246.9ms
# Speed: 4.0ms preprocess, 246.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 270.6ms
# Speed: 3.5ms preprocess, 270.6ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 271.7ms
# Speed: 2.9ms preprocess, 271.7ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 335.1ms
# Speed: 3.0ms preprocess, 335.1ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 365.7ms
# Speed: 5.1ms preprocess, 365.7ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 368.7ms
# Speed: 3.8ms preprocess, 368.7ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 352.2ms
# Speed: 5.4ms preprocess, 352.2ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 393.7ms
# Speed: 5.9ms preprocess, 393.7ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 380.4ms
# Speed: 5.7ms preprocess, 380.4ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 238.7ms
# Speed: 3.0ms preprocess, 238.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 259.3ms
# Speed: 3.8ms preprocess, 259.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 244.8ms
# Speed: 2.7ms preprocess, 244.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 263.6ms
# Speed: 3.8ms preprocess, 263.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 281.1ms
# Speed: 6.0ms preprocess, 281.1ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 244.9ms
# Speed: 3.9ms preprocess, 244.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 octagon-churchs, 228.8ms
# Speed: 4.7ms preprocess, 228.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 239.8ms
# Speed: 6.4ms preprocess, 239.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 230.3ms
# Speed: 4.6ms preprocess, 230.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 274.8ms
# Speed: 4.3ms preprocess, 274.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 267.5ms
# Speed: 3.1ms preprocess, 267.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 262.1ms
# Speed: 5.9ms preprocess, 262.1ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 375.4ms
# Speed: 5.8ms preprocess, 375.4ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 291.8ms
# Speed: 5.2ms preprocess, 291.8ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 248.8ms
# Speed: 27.4ms preprocess, 248.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 228.6ms
# Speed: 2.9ms preprocess, 228.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 octagon-church, 233.2ms
# Speed: 2.6ms preprocess, 233.2ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 233.6ms
# Speed: 2.5ms preprocess, 233.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 238.8ms
# Speed: 4.1ms preprocess, 238.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 234.5ms
# Speed: 4.7ms preprocess, 234.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 242.1ms
# Speed: 4.0ms preprocess, 242.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 243.0ms
# Speed: 3.0ms preprocess, 243.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 391.8ms
# Speed: 5.6ms preprocess, 391.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 square-church, 397.9ms
# Speed: 5.5ms preprocess, 397.9ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 420.8ms
# Speed: 6.9ms preprocess, 420.8ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 417.9ms
# Speed: 8.2ms preprocess, 417.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 429.4ms
# Speed: 14.4ms preprocess, 429.4ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 333.2ms
# Speed: 9.1ms preprocess, 333.2ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 233.8ms
# Speed: 5.2ms preprocess, 233.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 240.7ms
# Speed: 3.0ms preprocess, 240.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 octagon-church, 265.6ms
# Speed: 4.0ms preprocess, 265.6ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 249.0ms
# Speed: 2.7ms preprocess, 249.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 249.5ms
# Speed: 4.3ms preprocess, 249.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 242.8ms
# Speed: 3.2ms preprocess, 242.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 237.3ms
# Speed: 4.0ms preprocess, 237.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 254.3ms
# Speed: 4.5ms preprocess, 254.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 249.9ms
# Speed: 3.4ms preprocess, 249.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 octagon-church, 268.0ms
# Speed: 4.9ms preprocess, 268.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 262.8ms
# Speed: 5.1ms preprocess, 262.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 256.9ms
# Speed: 4.2ms preprocess, 256.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 248.4ms
# Speed: 2.9ms preprocess, 248.4ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 247.1ms
# Speed: 4.3ms preprocess, 247.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 267.1ms
# Speed: 2.8ms preprocess, 267.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 260.7ms
# Speed: 4.3ms preprocess, 260.7ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 257.2ms
# Speed: 3.1ms preprocess, 257.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 267.5ms
# Speed: 4.1ms preprocess, 267.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 261.6ms
# Speed: 6.1ms preprocess, 261.6ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 281.6ms
# Speed: 6.2ms preprocess, 281.6ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 264.5ms
# Speed: 5.0ms preprocess, 264.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 273.8ms
# Speed: 3.2ms preprocess, 273.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 271.7ms
# Speed: 3.1ms preprocess, 271.7ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 420.4ms
# Speed: 5.4ms preprocess, 420.4ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 355.7ms
# Speed: 5.6ms preprocess, 355.7ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 416.8ms
# Speed: 3.3ms preprocess, 416.8ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 423.6ms
# Speed: 3.9ms preprocess, 423.6ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 409.7ms
# Speed: 12.7ms preprocess, 409.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 294.7ms
# Speed: 5.4ms preprocess, 294.7ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 254.8ms
# Speed: 5.0ms preprocess, 254.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 253.8ms
# Speed: 3.8ms preprocess, 253.8ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 265.6ms
# Speed: 3.1ms preprocess, 265.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 276.2ms
# Speed: 6.3ms preprocess, 276.2ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 254.6ms
# Speed: 2.8ms preprocess, 254.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 246.5ms
# Speed: 4.1ms preprocess, 246.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 288.6ms
# Speed: 6.1ms preprocess, 288.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 279.6ms
# Speed: 3.0ms preprocess, 279.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 269.4ms
# Speed: 7.0ms preprocess, 269.4ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 246.3ms
# Speed: 4.9ms preprocess, 246.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 234.8ms
# Speed: 3.8ms preprocess, 234.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 248.3ms
# Speed: 2.6ms preprocess, 248.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 235.3ms
# Speed: 2.4ms preprocess, 235.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 249.5ms
# Speed: 4.8ms preprocess, 249.5ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 octagon-church, 261.6ms
# Speed: 3.4ms preprocess, 261.6ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 251.2ms
# Speed: 5.8ms preprocess, 251.2ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 274.0ms
# Speed: 7.3ms preprocess, 274.0ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 263.3ms
# Speed: 2.9ms preprocess, 263.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 267.1ms
# Speed: 3.0ms preprocess, 267.1ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 287.2ms
# Speed: 5.0ms preprocess, 287.2ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 263.3ms
# Speed: 3.0ms preprocess, 263.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 228.8ms
# Speed: 3.8ms preprocess, 228.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 336.6ms
# Speed: 4.6ms preprocess, 336.6ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 422.4ms
# Speed: 8.5ms preprocess, 422.4ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 383.1ms
# Speed: 4.1ms preprocess, 383.1ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 370.3ms
# Speed: 5.4ms preprocess, 370.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 366.4ms
# Speed: 3.4ms preprocess, 366.4ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 318.4ms
# Speed: 5.3ms preprocess, 318.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 octagon-church, 228.7ms
# Speed: 4.7ms preprocess, 228.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 222.7ms
# Speed: 3.8ms preprocess, 222.7ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 244.1ms
# Speed: 4.9ms preprocess, 244.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 284.0ms
# Speed: 3.2ms preprocess, 284.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 262.1ms
# Speed: 6.6ms preprocess, 262.1ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 octagon-church, 277.2ms
# Speed: 5.7ms preprocess, 277.2ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 261.4ms
# Speed: 4.9ms preprocess, 261.4ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 252.3ms
# Speed: 5.1ms preprocess, 252.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 229.9ms
# Speed: 2.5ms preprocess, 229.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 231.1ms
# Speed: 4.9ms preprocess, 231.1ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 268.7ms
# Speed: 5.9ms preprocess, 268.7ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 265.7ms
# Speed: 3.1ms preprocess, 265.7ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 234.7ms
# Speed: 3.7ms preprocess, 234.7ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 221.5ms
# Speed: 3.8ms preprocess, 221.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 229.7ms
# Speed: 2.5ms preprocess, 229.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 291.0ms
# Speed: 4.8ms preprocess, 291.0ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 259.1ms
# Speed: 3.1ms preprocess, 259.1ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# ...
# Coordinates: (9.062967849834552, 38.68808773072912), Type: circle-church, Name: Unknown Church
# Coordinates: (9.067141929371473, 38.600484855429976), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.068686784344832, 38.603087204306966), Type: square-church, Name: Unknown Church
# Coordinates: (9.066079664306212, 38.6067868923443), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.068801847429919, 38.61308194585522), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.067188523168282, 38.61393488494751), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.067764395583378, 38.61899183824419), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.068246641613582, 38.64154011586412), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.068421598050096, 38.648475402655386), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.068381170346294, 38.65160026627931), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.068718690045099, 38.649753525740586), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.066647370161066, 38.66544315727641), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.06869757008266, 38.671128409230214), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.068608756446217, 38.68449499503715), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.068626880815854, 38.68449709815489), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.068540267072695, 38.68472637451645), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.066780156913229, 38.69095513743507), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.071694266379378, 38.61385601977727), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.069158494025785, 38.61874598776765), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.068899443696187, 38.625106761297104), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.069062585112825, 38.625483853331026), Type: square-church, Name: Unknown Church
# Coordinates: (9.069065999681518, 38.62563281617836), Type: square-church, Name: Unknown Church
# Coordinates: (9.068908341170433, 38.63529876556739), Type: square-church, Name: Unknown Church
# Coordinates: (9.069204902930398, 38.64390881971393), Type: square-church, Name: Unknown Church
# Coordinates: (9.069798530933076, 38.64967322820615), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.071703633505242, 38.65199845916291), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.069120922937229, 38.66478411601971), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.069125430898838, 38.66507288702282), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.071753677376522, 38.66958818440512), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.071210178212263, 38.68636286530021), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.074638736876452, 38.610030259471024), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.073521179522842, 38.617398465332734), Type: circle-church, Name: Unknown Church
# Coordinates: (9.075145311419464, 38.621107831273015), Type: square-church, Name: Unknown Church
# Coordinates: (9.075175581926377, 38.621935907582326), Type: square-church, Name: Unknown Church
# Coordinates: (9.072780626837536, 38.62508600043073), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.072105773209161, 38.62898087528285), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.073859785444014, 38.63829963033564), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.073336773075097, 38.64489393207417), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.074435901811949, 38.64796936633267), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.073597810475343, 38.65310194335338), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.074715653494334, 38.65598818495707), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.072105572486825, 38.659163066714754), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.074870311497321, 38.658398129936494), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.07486424012494, 38.658368001427654), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.073238865641743, 38.66379027067286), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.074938690459824, 38.66825103908512), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.072484986184577, 38.67451357084101), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.074830931156141, 38.6779506170089), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.073613395854167, 38.67576481209379), Type: square-church, Name: Unknown Church
# Coordinates: (9.072526105239078, 38.67476128053129), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.07367135994267, 38.67617635036968), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.075281947676464, 38.67868388622453), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.072111090105444, 38.684327531033134), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.074799282747472, 38.685162167103925), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.074106485603403, 38.68974870323392), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.07374900602888, 38.68784524569054), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.073129584023011, 38.68802695739452), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.075351509413151, 38.61809997753551), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.07535327651471, 38.618081969063894), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.07533741203146, 38.61921705632283), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.076041462528982, 38.62551789021685), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.07582406662589, 38.62316230623576), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.075360941300437, 38.632060353188656), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.07691454251598, 38.63610308921502), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.076707050604618, 38.640777662473894), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.07779993649276, 38.6391955888845), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.07736592527397, 38.64629731265658), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.076605969317095, 38.65726765726535), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.078393716156382, 38.65917461444603), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.077943818395752, 38.66157116848084), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.076680473315436, 38.66447691559926), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.077044023799724, 38.66311568377629), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.077082542749912, 38.67705221663153), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.077165675461877, 38.67618714552963), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.076708588494407, 38.678096680165005), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.078317361385633, 38.68274452951647), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.078052902323249, 38.68413328547372), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.075350692577862, 38.68893819828234), Type: circle-church, Name: Unknown Church
# Coordinates: (9.08008808827388, 38.61570593867064), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.081071247815109, 38.61905025138939), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.081357999108876, 38.62534327380595), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.079515979239943, 38.664823803458916), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.080856536318455, 38.66899642381818), Type: circle-church, Name: Unknown Church
# Coordinates: (9.079937898755938, 38.671472446579145), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.081689441575499, 38.67236885740456), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.078828064468032, 38.67222743442405), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.079909747338714, 38.67481916747042), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.080954187770956, 38.68128694332316), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.081612382703199, 38.68894382486839), Type: circle-church, Name: Unknown Church
# Coordinates: (9.08276746037326, 38.62114731663844), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.083239337636856, 38.61942210719571), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.08236556661721, 38.65538272822748), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.082119308024792, 38.67269755342068), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.084246748588225, 38.6747432889167), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.084223697358192, 38.674748282357996), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.085453192671606, 38.60135735018841), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.087803390664812, 38.618100345050294), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.08809483411846, 38.64454526153439), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.08994508284659, 38.621904622996254), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.089801266480865, 38.62066598053351), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.090485540927473, 38.65426953309743), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.089897956154703, 38.67779831543258), Type: square-church, Name: Unknown Church
# Coordinates: (9.091571729796057, 38.60698974955704), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.091880115980013, 38.62941311475051), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.094780825114203, 38.65024310409222), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.099352000472072, 38.60337391566726), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.100290269915565, 38.62141365505288), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.103153727869799, 38.612908976260265), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.10686470141958, 38.611672637382135), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.106381802175585, 38.64691417974129), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.104678795831619, 38.65502102954887), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.107940077446338, 38.65449335256474), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.107995600618622, 38.66804379220757), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.107940707548606, 38.66894330466655), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.111365279870002, 38.615468896920966), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.116936435939826, 38.64828545157921), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.114780628823453, 38.663361182022705), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.117484064356672, 38.60596667130764), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.12043051776085, 38.64279779414787), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.118019308446828, 38.67587485451799), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.123179531301796, 38.602895774256254), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.121906368893145, 38.65319325560588), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.123513900894054, 38.68928865347437), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.123903481216907, 38.62350407158982), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.123847231342353, 38.62994510074083), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.124228696469794, 38.6541749791425), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.125037582048762, 38.65569014751632), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.126902891549173, 38.655567301664426), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.125130982792701, 38.66751142983591), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.125705626229843, 38.678477374960075), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.130230097370248, 38.62350124525848), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.129493402208455, 38.62377023067461), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.129497230818469, 38.62435365636252), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.1271771200495, 38.661946196609996), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.129606220680712, 38.67088468311504), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.127808456277466, 38.67077003601553), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.129255214646077, 38.677844210557495), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.129633046703097, 38.68574135987094), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.130027983215678, 38.686958037833854), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.129098679887083, 38.685942718313925), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.12934620381136, 38.68553078082454), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.130990716101644, 38.68435698004423), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.135791096050427, 38.63093764895412), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.134623508472709, 38.660396218760894), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.133775738226332, 38.660770856127996), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.134090605180962, 38.67104649166094), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.134016334456739, 38.68769248718874), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.137553465009615, 38.61479272649576), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.138130254329623, 38.61514008642325), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.13886047579732, 38.66136827834258), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.139056191047384, 38.66156960103377), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.141858990483328, 38.60868419954414), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.142456910251738, 38.61169704006123), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.140946660612864, 38.62770123417633), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.140375414434867, 38.66289467706761), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.141353281494851, 38.672073707617265), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.145815566867347, 38.60960632605032), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.144210242624192, 38.61259929175687), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.145882731000235, 38.628385423843795), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.143861350474817, 38.67735564987615), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.144603530835967, 38.67817244102375), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.14346383722967, 38.68039146067327), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.14460899710662, 38.678368495413615), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.149277141972817, 38.62126292170494), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.149499648549066, 38.65020110057605), Type: octagon-church, Name: Unknown Church
# Coordinates: (9.149162197934249, 38.67827018714762), Type: octagon-church, Name: Unknown Church
